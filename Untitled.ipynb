# %%
import pandas_profiling
import pandas as pd
df=pd.read_csv('operator.csv',names=['id','name','login_time','opr_time','boom','bucket'],header=None)
print(df.head())
# Out:
#    id       name  login_time  opr_time  boom  bucket
# 0   0  operator0           0         0    50      50
# 1   1  operator1         500       400    50      50
# 2   2  operator2        1000       753    60      55
# 3   3  operator3         800       150    35      75

# %%
profile = pandas_profiling.ProfileReport(df)
profile.to_file(outputfile="output.html")

# %%
import seaborn as sb
import matplotlib.pyplot as plt
plt.show()
# %matplotlib inline
# Out:
# c:\users\hrishi\appdata\local\programs\python\python36\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
sb.pairplot(df)
